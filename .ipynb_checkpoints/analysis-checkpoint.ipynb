# %% [markdown]
# # NYC Airbnb Analysis

# %%
import csv
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import xgboost as xgb
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %% [markdown]
# ### Import and Clean Data

# %%
# Read in data
df = pd.read_csv('airbnbdata.csv')
df.columns.values.tolist()

# Drop irrelevant features
df.drop(['latitude','longitude','review_scores_location',
 'listing_url',
 'scrape_id',
 'last_scraped',
 'name',
 'description',
 'neighborhood_overview',
 'picture_url',
 'host_id',
 'host_url',
 'host_name',
 'host_since',
 'host_location',
 'host_about',
 'host_response_time',
 'host_response_rate',
 'host_acceptance_rate',
 'host_is_superhost',
 'host_thumbnail_url',
 'host_picture_url',
 'host_neighbourhood',
 'host_listings_count',
 'host_total_listings_count',
 'host_verifications',
 'host_has_profile_pic',
 'host_identity_verified',
 'neighbourhood', 'neighbourhood_cleansed',
 'property_type',
 'bathrooms_text',
 'beds', 'bathrooms',
 'amenities',
 'maximum_nights',
 'minimum_minimum_nights',
 'maximum_minimum_nights',
 'minimum_maximum_nights',
 'maximum_maximum_nights',
 'minimum_nights_avg_ntm',
 'maximum_nights_avg_ntm',
 'calendar_updated',
 'has_availability',
 'calendar_last_scraped',
 'number_of_reviews',
 'number_of_reviews_ltm',
 'number_of_reviews_l30d',
 'first_review',
 'last_review',
 'review_scores_rating',
 'review_scores_accuracy',
 'review_scores_cleanliness',
 'review_scores_checkin',
 'review_scores_communication',
 'review_scores_value',
 'license',
 'instant_bookable',
 'calculated_host_listings_count',
 'calculated_host_listings_count_entire_homes',
 'calculated_host_listings_count_private_rooms',
 'calculated_host_listings_count_shared_rooms',
 'reviews_per_month'],axis=1,inplace=True)

# Set property ID as index
df.set_index('id', inplace=True)

# Replace null values
df['bedrooms']=df['bedrooms'].fillna(1)

df = pd.get_dummies(df)

df.info()
# Out:
# /var/folders/3q/7fynlhf553j564109frc1vgm0000gn/T/ipykernel_4524/2006712366.py:2: DtypeWarning: Columns (67) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('airbnbdata.csv')
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 37410 entries, 2595.0 to 6.41241e+17
# Data columns (total 17 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   accommodates                                37410 non-null  int64
#  1   bedrooms                                    37410 non-null  float64
#  2   price                                       37410 non-null  int64
#  3   minimum_nights                              37410 non-null  int64
#  4   availability_30                             37410 non-null  int64
#  5   availability_60                             37410 non-null  int64
#  6   availability_90                             37410 non-null  int64
#  7   availability_365                            37410 non-null  int64
#  8   neighbourhood_group_cleansed_Bronx          37410 non-null  uint8
#  9   neighbourhood_group_cleansed_Brooklyn       37410 non-null  uint8
#  10  neighbourhood_group_cleansed_Manhattan      37410 non-null  uint8
#  11  neighbourhood_group_cleansed_Queens         37410 non-null  uint8
#  12  neighbourhood_group_cleansed_Staten Island  37410 non-null  uint8
#  13  room_type_Entire home/apt                   37410 non-null  uint8
#  14  room_type_Hotel room                        37410 non-null  uint8
#  15  room_type_Private room                      37410 non-null  uint8
#  16  room_type_Shared room                       37410 non-null  uint8
# dtypes: float64(1), int64(7), uint8(9)
# memory usage: 2.9 MB

# %%
df.head(n=10)
# Out:
#         accommodates  bedrooms  price  minimum_nights  availability_30  \
# id
# 2595.0             1       1.0    225              30                0
# 5121.0             2       1.0     60              30               30
# 5136.0             4       2.0    275              21                3
# 5178.0             2       1.0     68               2                3
# 5203.0             1       1.0     75               2                0
# 5295.0             2       1.0    135              30                0
# 5803.0             2       1.0    118               4                3
# 6848.0             3       1.0     84              30                0
# 6872.0             1       1.0     65              30                0
# 6990.0             1       1.0     62              30                0
#
#         availability_60  availability_90  availability_365  \
# id
# 2595.0                3               33               308
# 5121.0               60               90               365
# 5136.0                3                4               250
# 5178.0                5                9               172
# 5203.0                0                0                 0
# 5295.0                0               19                30
# 5803.0               12               37               312
# 6848.0                0               17               227
# 6872.0               29               59               334
# 6990.0                8                8               254
#
#         neighbourhood_group_cleansed_Bronx  \
# id
# 2595.0                                   0
# 5121.0                                   0
# 5136.0                                   0
# 5178.0                                   0
# 5203.0                                   0
# 5295.0                                   0
# 5803.0                                   0
# 6848.0                                   0
# 6872.0                                   0
# 6990.0                                   0
#
#         neighbourhood_group_cleansed_Brooklyn  \
# id
# 2595.0                                      0
# 5121.0                                      1
# 5136.0                                      1
# 5178.0                                      0
# 5203.0                                      0
# 5295.0                                      0
# 5803.0                                      1
# 6848.0                                      1
# 6872.0                                      0
# 6990.0                                      0
#
#         neighbourhood_group_cleansed_Manhattan  \
# id
# 2595.0                                       1
# 5121.0                                       0
# 5136.0                                       0
# 5178.0                                       1
# 5203.0                                       1
# 5295.0                                       1
# 5803.0                                       0
# 6848.0                                       0
# 6872.0                                       1
# 6990.0                                       1
#
#         neighbourhood_group_cleansed_Queens  \
# id
# 2595.0                                    0
# 5121.0                                    0
# 5136.0                                    0
# 5178.0                                    0
# 5203.0                                    0
# 5295.0                                    0
# 5803.0                                    0
# 6848.0                                    0
# 6872.0                                    0
# 6990.0                                    0
#
#         neighbourhood_group_cleansed_Staten Island  room_type_Entire home/apt  \
# id
# 2595.0                                           0                          1
# 5121.0                                           0                          0
# 5136.0                                           0                          1
# 5178.0                                           0                          0
# 5203.0                                           0                          0
# 5295.0                                           0                          1
# 5803.0                                           0                          0
# 6848.0                                           0                          1
# 6872.0                                           0                          0
# 6990.0                                           0                          0
#
#         room_type_Hotel room  room_type_Private room  room_type_Shared room
# id
# 2595.0                     0                       0                      0
# 5121.0                     0                       1                      0
# 5136.0                     0                       0                      0
# 5178.0                     0                       1                      0
# 5203.0                     0                       1                      0
# 5295.0                     0                       0                      0
# 5803.0                     0                       1                      0
# 6848.0                     0                       0                      0
# 6872.0                     0                       1                      0
# 6990.0                     0                       1                      0

# %%
plt.figure(figsize=(10,5))
plt.rc(['axes'], labelsize=16, titlesize=16)
plt.title("Price Distribution")
sns.boxplot(x=df['price'])
# Out:
# <AxesSubplot: title={'center': 'Price Distribution'}, xlabel='price'>

# %%
df['price'].describe()
# Out:
# count    37410.000000
# mean       190.775221
# std        342.491748
# min          0.000000
# 25%         75.000000
# 50%        125.000000
# 75%        203.000000
# max      12900.000000
# Name: price, dtype: float64

# %%
Visualizing the data after treating the outlier

plt.boxplot(c, vert=False)
plt.title("Boxplot of the sample after treating the outliers")
plt.xlabel("Sample")

# %% [markdown]
# ### Remove Outliers

# %%
percentile25 = df['price'].quantile(0.25)
percentile75 = df['price'].quantile(0.75)
print("75th quartile: ",percentile75)
print("25th quartile: ",percentile25)

iqr = percentile75 - percentile25
print ("IQR: ",iqr)

upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 - 1.5 * iqr
print("upper limit: ", upper_limit)
print("lower limit: ", lower_limit)
df[df['price'] > upper_limit].count()

df = df[df['price'] < upper_limit]
df.shape

plt.figure(figsize=(10,5))
plt.rc(['axes'], labelsize=16, titlesize=16)
plt.title("Price Distribution")
sns.boxplot(x=df['price'])
# Out:
# 75th quartile:  175.0
# 25th quartile:  70.0
# IQR:  105.0
# upper limit:  332.5
# lower limit:  -87.5
# <AxesSubplot: title={'center': 'Price Distribution'}, xlabel='price'>

# %%
df['price'].describe()
# Out:
# count    33158.000000
# mean       128.390705
# std         71.524477
# min          0.000000
# 25%         70.000000
# 50%        110.000000
# 75%        175.000000
# max        332.000000
# Name: price, dtype: float64

# %% [markdown]
# ### Data Exploration

# %%
# Distribution of each originally numerical feature
df.hist(['accommodates','bedrooms','price','minimum_nights','availability_30','availability_60','availability_90','availability_365'], figsize=(8,8))
# Out:
# array([[<AxesSubplot: title={'center': 'accommodates'}>,
#         <AxesSubplot: title={'center': 'bedrooms'}>,
#         <AxesSubplot: title={'center': 'price'}>],
#        [<AxesSubplot: title={'center': 'minimum_nights'}>,
#         <AxesSubplot: title={'center': 'availability_30'}>,
#         <AxesSubplot: title={'center': 'availability_60'}>],
#        [<AxesSubplot: title={'center': 'availability_90'}>,
#         <AxesSubplot: title={'center': 'availability_365'}>,
#         <AxesSubplot: >]], dtype=object)

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ### Split

# %%
# Identify independent and dependent variables
X = df.drop(['price'], axis=1)
y = df['price']

# Split train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)
print(len(X_train), len(X_test), len(y_train), len(y_test))
# Out:
# 26526 6632 26526 6632

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 33158 entries, 2595.0 to 6.41241e+17
# Data columns (total 16 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   accommodates                                33158 non-null  int64
#  1   bedrooms                                    33158 non-null  float64
#  2   minimum_nights                              33158 non-null  int64
#  3   availability_30                             33158 non-null  int64
#  4   availability_60                             33158 non-null  int64
#  5   availability_90                             33158 non-null  int64
#  6   availability_365                            33158 non-null  int64
#  7   neighbourhood_group_cleansed_Bronx          33158 non-null  uint8
#  8   neighbourhood_group_cleansed_Brooklyn       33158 non-null  uint8
#  9   neighbourhood_group_cleansed_Manhattan      33158 non-null  uint8
#  10  neighbourhood_group_cleansed_Queens         33158 non-null  uint8
#  11  neighbourhood_group_cleansed_Staten Island  33158 non-null  uint8
#  12  room_type_Entire home/apt                   33158 non-null  uint8
#  13  room_type_Hotel room                        33158 non-null  uint8
#  14  room_type_Private room                      33158 non-null  uint8
#  15  room_type_Shared room                       33158 non-null  uint8
# dtypes: float64(1), int64(6), uint8(9)
# memory usage: 2.3 MB

# %% [markdown]
# ### Multiple Regression

# %%
# Fit regression model
mlr = LinearRegression()
mlr.fit(X,y)

# Predict price
y_pred = mlr.predict(X)
print('Results for multiple regression on training data')
print('MAE is ', mean_absolute_error(y, y_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y, y_pred)))
print('MSE is ', mean_squared_error(y,y_pred))
print('R^2 ', r2_score(y,y_pred))

y_test_pred = mlr.predict(X_test)
print()
print('Results for multiple regression on test data')
print('MAE is ', mean_absolute_error(y_test, y_test_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y_test,
y_test_pred)))
print('MSE is ', mean_squared_error(y_test, y_test_pred))
print('R^2 ', r2_score(y_test,y_test_pred))
# Out:
# Results for multiple regression on training data
# MAE is  38.836207233387405
# RMSE is  51.529976726678726
# MSE is  2655.338501452051
# R^2  0.48093276662873374
#
# Results for multiple regression on test data
# MAE is  38.988705555387504
# RMSE is  52.07567641477023
# MSE is  2711.8760740558564
# R^2  0.4753561301327358

# %% [markdown]
# ### Decision Tree Regression

# %%
# Fit regression model
dt = DecisionTreeRegressor()
dt.fit(X, y)

# Predict price
y_pred = dt.predict(X)
print('Results for decision tree on training data')
print('MAE is ', mean_absolute_error(y, y_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y, y_pred)))
print('MSE is ', mean_squared_error(y,y_pred))
print('R^2 ', r2_score(y,y_pred))

y_test_pred = dt.predict(X_test)
print()
print('Results for decision tree on test data')
print('MAE is ', mean_absolute_error(y_test, y_test_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y_test,
y_test_pred)))
print('MSE is ', mean_squared_error(y_test, y_test_pred))
print('R^2 ', r2_score(y_test,y_test_pred))
# Out:
# Results for decision tree on training data
# MAE is  15.732948373101976
# RMSE is  31.23449423800915
# MSE is  975.593630304227
# R^2  0.8092903461085188
#
# Results for decision tree on test data
# MAE is  15.59466132840639
# RMSE is  31.59388211073869
# MSE is  998.1733868272541
# R^2  0.8068917848150985

# %%
# Visualize weight of each feature

ft_weights_dt = pd.DataFrame(dt.feature_importances_, columns=['weight'], index=X.columns)
ft_weights_dt.sort_values('weight', inplace=True)
ft_weights_dt
# Out:
#                                               weight
# room_type_Shared room                       0.000966
# neighbourhood_group_cleansed_Bronx          0.001776
# neighbourhood_group_cleansed_Staten Island  0.001894
# room_type_Hotel room                        0.002938
# neighbourhood_group_cleansed_Queens         0.002956
# room_type_Private room                      0.003064
# neighbourhood_group_cleansed_Brooklyn       0.009435
# bedrooms                                    0.027033
# availability_30                             0.051447
# neighbourhood_group_cleansed_Manhattan      0.057573
# availability_60                             0.058874
# availability_90                             0.076996
# minimum_nights                              0.090916
# accommodates                                0.091951
# availability_365                            0.115232
# room_type_Entire home/apt                   0.406948

# %%
plt.figure(figsize=(10,6))
plt.bar([x for x in range(len(dt.feature_importances_))], dt.feature_importances_)
plt.xlabel('Feature')
plt.ylabel('Weight')
plt.title('Weight of each Feature in Price Prediction')
plt.show()

# %%
# Visualize actual vs predicted price

plt.figure(figsize=(10,7))
scatter = plt.scatter(y_test, y_test_pred, marker=".")
plt.title("Actual Test Price vs Predicted Test Price")
plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'k--', lw=4)
plt.show()

# %% [markdown]
# ### Random Forest Regression

# %%
# Fit regression model
rf = RandomForestRegressor()
rf.fit(X,y)
y_pred = rf.predict(X)

# Predict price
y_pred = rf.predict(X)
print('Results for random forest on training data')
print('MAE is ', mean_absolute_error(y, y_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y, y_pred)))
print('MSE is ', mean_squared_error(y,y_pred))
print('R^2 ', r2_score(y,y_pred))

y_test_pred = rf.predict(X_test)
print()
print('Results for random forest on test data')
print('MAE is ', mean_absolute_error(y_test, y_test_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y_test,
y_test_pred)))
print('MSE is ', mean_squared_error(y_test, y_test_pred))
print('R^2 ', r2_score(y_test,y_test_pred))
# Out:
# Results for random forest on training data
# MAE is  23.142877465972298
# RMSE is  34.25483532551702
# MSE is  1173.393743178289
# R^2  0.7706242561565528
#
# Results for random forest on test data
# MAE is  23.165674512500065
# RMSE is  34.63215679404347
# MSE is  1199.3862842072112
# R^2  0.7679648168173525

# %% [markdown]
# ### XGBoost

# %%
# Fit regression model
xgb_reg = xgb.XGBRegressor()
xgb_reg.fit(X,y)

# Predict price
y_pred = xgb_reg.predict(X)
print('Results for xgboost on training data')
print('MAE is ', mean_absolute_error(y, y_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y, y_pred)))
print('MSE is ', mean_squared_error(y,y_pred))
print('R^2 ', r2_score(y,y_pred))

y_test_pred = xgb_reg.predict(X_test)
print()
print('Results for decision tree on test data')
print('MAE is ', mean_absolute_error(y_test, y_test_pred))
print('RMSE is ', np.sqrt(mean_squared_error(y_test,
y_test_pred)))
print('MSE is ', mean_squared_error(y_test, y_test_pred))
print('R^2 ', r2_score(y_test,y_test_pred))
# Out:
# Results for xgboost on training data
# MAE is  32.33844993623406
# RMSE is  43.684139178629096
# MSE is  1908.3040157778373
# R^2  0.6269635357754157
#
# Results for decision tree on test data
# MAE is  32.5349746036587
# RMSE is  44.187786191083624
# MSE is  1952.5604484689206
# R^2  0.6222545419258727

# %% [markdown]
# # Results
# | Model | Training Features | Set | RMSE | R2 (%) |
# |:---|:---|:---|:---|:---|
# |Multiple Regression|Independent|Training|51.53|48.09|
# |Multiple Regression|Independent|Test|52.08|47.54|
# |Decision Tree|Independent|Training|31.23|80.93|
# |Decision Tree|Independent|Test|31.59|80.69|
# |Random Forest|Independent|Training|34.25|77.06|
# |Random Forest|Independent|Test|34.63|76.80|
# |XGBoost|Independent|Training|43.68|62.70|
# |XGBoost|Independent|Test|44.19|62.23|
